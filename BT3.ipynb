# %%
#W3A1
n = input("Nhập vào một số nguyên dương n: ")
print(n[::-1])
# Out:
# 54321

# %%
#W3A2
a, b = map(int, input("Nhập vào hai số nguyên a và b: ").split())
a = a ^ b
b = a ^ b
a = a ^ b
print("a =", a)
print("b =", b)
# Out:
# a = 10
# b = 5

# %%
#W3A3
n = int(input("Nhập vào một số nguyên dương n: "))
if n > 0 and (n & (n - 1)) == 0:
    print(n, "là lũy thừa của 2")
else:
    print(n, "không phải là lũy thừa của 2")
# Out:
# 16 là lũy thừa của 2

# %%
#W3A4
m,n = map(float, input("Nhập vào hai số nguyên dương m và n: ").split())
print("Chia m cho n làm tròn xuống được:", int(m//n))
# Out:
# Chia m cho n làm tròn xuống được: 0

# %%
#W3A5
m,n = map(float, input("Nhập vào hai số nguyên dương m và n: ").split())
print("Chia m cho n làm tròn lên được:", int(-(-m//n)))
# Out:
# Chia m cho n làm tròn lên được: 1

# %%
#W3A6
n = int(input("Nhập vào một số nguyên dương n: "))
if n % 2:
    print(n, "ODD")
else:
    print(n, "EVEN")
# Out:
# 2 EVEN

# %%
#W3A7
a,b = map(int, input("Nhập vào hai số nguyên a và b: ").split())
if a < 0 and b < 0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#W3A8
a = input("Nhập vào một chuỗi a: ")
b = input("Nhập vào một chuỗi b: ")
if len(a) > len(b):
    print("True")
else:
    print("False")
# Out:
# False

# %%
#W3A9
a,b,c = map(int, input("Nhập vào ba số nguyên dương a, b và c: ").split())
if a + b > c and a + c > b and b + c > a:
    print("Yes")
else:
    print("No")

# %%
#W3A10
a, b, c,d = map(int, input("Nhập vào một danh sách các số nguyên: ").split())
print("Số lớn nhất trong danh sách là:", max(a,b,c,d))
# Out:
# Số lớn nhất trong danh sách là: 5

# %%
#W3A11
a,b,c = map(int, input("Nhập vào ba số nguyên dương a, b và c: ").split())
if a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print("Tam giác đều")
    elif a == b or a == c or b == c:
        print("Tam giác cân")
    else:
        print("Tam giác thường")
else:
    print("Không phải tam giác")
# Out:
# Tam giác đều

# %%
#W3A12
n = int(input("Nhập vào một năm: "))
if (n % 4 == 0 and n % 100 != 0) or (n % 400 == 0):
    print(n, "Yes")
else:
    print(n, "No")

# %%
#W3A13
n = int(input("Nhập vào số điện n kWh: "))
if n <= 50:
    tien = n * 1500
elif n <= 100:
    tien = 50 * 1500 + (n - 50) * 2000
else:
    tien = 50 * 1500 + 50 * 2000 + (n - 100) * 3000
print("Tiền điện phải trả là:", tien, "đồng")
# Out:
# Tiền điện phải trả là: 235000 đồng

# %%
#W3A14
a,b = map(float, input("Nhập vào hai số a và b: ").split())
if a == 0:
    if b == 0:
        print("Phương trình có vô số nghiệm")
    else:
        print("Phương trình vô nghiệm")
else:
    print("Phương trình có nghiệm duy nhất x =", round(-b/a,2))

# %%
#W3A15
n = float(input("Nhập vào học lực: "))
if n < 5.0:
    print("Yếu")
elif n < 6.5:
    print("Trung bình")
elif n < 8.0:
    print("Khá")
else:
    print("Giỏi")
# Out:
# Khá

# %%
#W3A16
n = float(input("Nhập một số thực n: "))
def tron_len(a):
    if a % 1 == 0:
        print(a)
    else:
        print(a//1 + 1)
def tron_xuong(a):
    if a % 1 == 0:
        print(a)
    else:
        print(a//1)
def tron_nearest(a):
    if a % 1 == 0:
        print(a)
    elif a % 1 < 0.5:
        print(a//1)
    else:
        print(a//1 + 1)

tron_len(n)
tron_xuong(n)
tron_nearest(n)
# Out:
# 4.0
# 3.0
# 4.0
