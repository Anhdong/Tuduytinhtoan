# %%
#W2A1
print("hello world")
# Out:
# hello world

# %%
#w2A2
print("hello "+input("Nhập tên của bạn:"))
# Out:
# hello tèo

# %%
#W2A3
a, b = int(input("Nhập số a:")), int(input("Nhập số b:"))
print("Tổng của a và b là:", a+b)
print("Hiệu của a và b là:", a-b)
print("Tích của a và b là:", a*b)
print("Thương của a và b là:", a/b)
print("Phần dư của a và b là:", a%b)
print("Phần nguyên của a và b là:",a//b)
# Out:
# Tổng của a và b là: 19
# Hiệu của a và b là: 1
# Tích của a và b là: 90
# Thương của a và b là: 1.1111111111111112
# Phần dư của a và b là: 1
# Phần nguyên của a và b là: 1

# %%
#W2A4
scores = list(map(int, input().split()))
print("Điểm trung bình là:", (scores[0]+scores[1]+scores[2] + (scores[3]+scores[4])*2 + (scores[5])*3)/10)
# Out:
# Điểm trung bình là: 2.6

# %%
#W2A5
a, b = map(int, input().split())
print(a**b)
# Out:
# 32

# %%
#W2A6
character = input("Nhập ký tự: ")
#in ra mã unicode của ký tự
print("Mã unicode của ký tự", character, "là:", ord(character))
#in ra ký tự hoa từ mã unicode
print("Ký tự hoa từ mã unicode", ord(character), "là:", chr(ord(character)-32))
# Out:
# Mã unicode của ký tự f là: 102
# Ký tự hoa từ mã unicode 102 là: F

# %%
#W2A7
print(((13**2)*3)+5)
print(13**2*3+5)
# Out:
# 512
# 512

# %%
#W2A8
#Đổi độ C sang độ F
c = float(input("Nhập độ C: "))
f = (9*c)/5 + 32
print("Độ F tương ứng là:", f)
# Out:
# Độ F tương ứng là: 32.0

# %%
#W2A9
x = int(input("Nhập giá tiền đồng hồ: "))
print("Giá tiền sau thuế và vận chuyến là:", (x+10)*1.3*1.1, "USD")
# Out:
# Giá tiền sau thuế và vận chuyến là: 28.6 USD

# %%
#W2A10
a,b,c = input("nhập tên: ").split()
print(f"Hi {c}, {b} and {a}")
# Out:
# Hi nu, hai and nam

# %%
#W2A11
# chuyển từ h giờ và m phút sang giây
h, m = map(int, input("Nhập giờ và phút: ").split())
print("Tổng số giây là:", h*3600 + m*60)

# %%
#W2A12
n = int(input("Độ dài cạnh của khối rubik: "))
#số miếng dán
print("Số miếng dán là:", 6*n**2)
# Out:
# Số miếng dán là: 54

# %%
#W2A13
#tìm tích a và b
a, b = map(int, input("Nhập a và b: ").split())
print("Tích của a và b là:", a*b)
# Out:
# Tích của a và b là: 20

# %%
#W2A14
a, b = map(int, input("Nhập a và b: ").split())
a, b = b, a 
print("Giá trị a sau khi đổi là:", a)
print("Giá trị b sau khi đổi là:", b)
# Out:
# Giá trị a sau khi đổi là: 3
# Giá trị b sau khi đổi là: 2

# %%
#W2A15
n = int(input("Nhập số nguyên dương n: "))

print("Số sao là ",6 * n * (n - 1) + 1)
# Out:
# Số sao là  37

# %%
#W2A16
print("spring\nsummer\nfall\nwinter\n")
# Out:
# spring
#  summer
#  fall
#  winter

# %%
#W2A17
for i in range(1,6,2):
    print("*"*i)
# Out:
# *
# ***
# *****

# %%
#W2A18
print("### # #  ### ###\n #  #  #  #   #\n #  #  #  #   #\n #  #  #  #   #\n #  # #   #   #")
# Out:
# ### # #  ### ###
#  #  #  #  #   #
#  #  #  #  #   #
#  #  #  #  #   #
#  #  # #   #   #

# %%
#W2A19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
for i in range(1,11):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
